# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
spx = pd.read_csv('drive/MyDrive/HyperPlanarTradingApp/TVC_SPX, 1D.csv')

spx['time'] = pd.to_datetime(spx['time'].str[:10], format='%Y/%m/%d')
spx.set_index('time', inplace=True)

print(spx.head())
# Out:
#             open  high   low  close
# time
# 1871-02-01  4.50  4.50  4.50   4.50
# 1871-03-01  4.61  4.61  4.61   4.61
# 1871-05-01  4.86  4.86  4.86   4.86
# 1871-06-01  4.82  4.82  4.82   4.82
# 1871-08-01  4.79  4.79  4.79   4.79

# %%
plt.plot(spx)
plt.figure(figsize=(25,3))

plt.show()
